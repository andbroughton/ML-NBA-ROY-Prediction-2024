# %%
import pandas as pd

# %%
roys = pd.read_csv("roys.csv")

# %%
roys
# Out:
#      Unnamed: 0 Rank              Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             1    2            Yao Ming   22  HOU   45.0    405.0      585
# 1             2    3        Caron Butler   22  MIA   13.0    179.0      585
# 2             3    4       Manu Ginóbili   25  SAS    0.0      5.0      585
# 3             4    5         Drew Gooden   21  TOT    0.0      3.0      585
# 4             5    6                Nenê   20  DEN    0.0      2.0      585
# ..          ...  ...                 ...  ...  ...    ...      ...      ...
# 163           1    2      Jalen Williams   21  OKC    0.0    241.0      500
# 164           2    3      Walker Kessler   21  UTA    2.0    114.0      500
# 165           3    4  Bennedict Mathurin   20  IND    0.0     27.0      500
# 166           4    5       Keegan Murray   22  SAC    0.0     21.0      500
# 167           5    6          Jaden Ivey   20  DET    0.0      3.0      500
#
# ...

# %%
roys = roys[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
roys.head()
# Out:
#           Player  Year  Pts Won  Pts Max  Share
# 0       Yao Ming  2003    405.0      585  0.692
# 1   Caron Butler  2003    179.0      585  0.306
# 2  Manu Ginóbili  2003      5.0      585  0.009
# 3    Drew Gooden  2003      3.0      585  0.005
# 4           Nenê  2003      2.0      585  0.003

# %%
rookies = pd.read_csv("rookies.csv")

# %%
rookies
# Out:
#       Unnamed: 0  Rk              Player                     Debut Age Yrs  \
# 0              0   1    Robert Archibald     Nov 9, '02, MEM @ DEN  22   2
# 1              1   2        Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4
# 2              2   3        Mike Batiste     Nov 1, '02, MEM @ DET  25   1
# 3              3   4        Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4
# 4              4   5       Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13
# ...          ...  ..                 ...                       ...  ..  ..
# 1894          88  81      Jalen Williams    Oct 19, '22, OKC @ MIN  21   2
# 1895          89  82     Jaylin Williams  Oct 23, '22, OKC vs. MIN  20   2
# 1896          90  83  Jeenathan Williams     Apr 2, '23, POR @ MIN  23   2
# 1897          91  84       Mark Williams    Oct 19, '22, CHO @ SAS  21   2
# 1898          92  85  Vince Williams Jr.    Oct 22, '22, MEM @ DAL  22   2
#
# ...

# %%
del rookies["Unnamed: 0"]
del rookies["Rk"]

# %%
rookies.head()
# Out:
#              Player                     Debut Age Yrs    G     MP    FG  \
# 0  Robert Archibald     Nov 9, '02, MEM @ DEN  22   2   44    328    15
# 1      Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4  105    831   106
# 2      Mike Batiste     Nov 1, '02, MEM @ DET  25   1   75   1248   197
# 3      Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4  162   1884   247
# 4     Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13  861  26901  5847
#
#      FGA  3P 3PA  ...    PF    PTS   FG%   3P%   FT%  MP.1 PTS.1 TRB.1 AST.1  \
# 0     53   0   0  ...    59     51  .283   NaN  .429   7.5   1.2   1.6   0.4
# 1    172   3   8  ...   140    286  .616  .375  .740   7.9   2.7   1.7   0.2
# 2    467  18  81  ...   120    481  .422  .222  .784  16.6   6.4   3.4   0.7
# 3    530   1   5  ...   324    637  .466  .200  .657  11.6   3.9   2.9   0.2
# 4  11221   1  14  ...  2612  13976  .521  .071  .722  31.2  16.2   9.5   2.2
#
#    Year
# 0  2003
# 1  2003
# 2  2003
# 3  2003
# 4  2003
#
# ...

# %%
rookies = rookies.drop(index = [20])

# %%
rookies.head(60)
# Out:
#                   Player                     Debut  Age  Yrs       G      MP  \
# 0       Robert Archibald     Nov 9, '02, MEM @ DEN   22    2      44     328
# 1           Maceo Baston  Feb 12, '03, TOR vs. ATL   27    4     105     831
# 2           Mike Batiste     Nov 1, '02, MEM @ DET   25    1      75    1248
# 3           Lonny Baxter   Nov 1, '02, CHI vs. NOH   24    4     162    1884
# 4          Carlos Boozer    Oct 29, '02, CLE @ SAC   21   13     861   26901
# 5            J.R. Bremer    Oct 31, '02, BOS @ WAS   22    2     100    1946
# 6            Devin Brown     Nov 4, '02, SAS @ MEM   24    8     465    9022
# 7              Pat Burke  Oct 29, '02, ORL vs. PHI   29    3     127    1293
# 8           Caron Butler  Oct 30, '02, MIA vs. ORL   22   14     881   28333
# 9          Rasual Butler  Oct 30, '02, MIA vs. ORL   23   13     809   17219
# 10            Dan Dickau    Oct 30, '02, ATL @ NJN   24    6     300    4617
# ...

# %%
rookies = rookies[~rookies["Age"].str.contains("Age", na=False)]

# %%
rookies.head(60)
# Out:
#                   Player                     Debut Age Yrs     G     MP    FG  \
# 0       Robert Archibald     Nov 9, '02, MEM @ DEN  22   2    44    328    15
# 1           Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4   105    831   106
# 2           Mike Batiste     Nov 1, '02, MEM @ DET  25   1    75   1248   197
# 3           Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4   162   1884   247
# 4          Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13   861  26901  5847
# 5            J.R. Bremer    Oct 31, '02, BOS @ WAS  22   2   100   1946   214
# 6            Devin Brown     Nov 4, '02, SAS @ MEM  24   8   465   9022  1174
# 7              Pat Burke  Oct 29, '02, ORL vs. PHI  29   3   127   1293   199
# 8           Caron Butler  Oct 30, '02, MIA vs. ORL  22  14   881  28333  4596
# 9          Rasual Butler  Oct 30, '02, MIA vs. ORL  23  13   809  17219  2293
# 10            Dan Dickau    Oct 30, '02, ATL @ NJN  24   6   300   4617   608
# ...

# %%
rookies = rookies[~rookies["MP"].str.contains("Totals", na=False)]

# %%
rookies.head(30)
# Out:
#                Player                     Debut Age Yrs     G     MP    FG  \
# 0    Robert Archibald     Nov 9, '02, MEM @ DEN  22   2    44    328    15
# 1        Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4   105    831   106
# 2        Mike Batiste     Nov 1, '02, MEM @ DET  25   1    75   1248   197
# 3        Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4   162   1884   247
# 4       Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13   861  26901  5847
# 5         J.R. Bremer    Oct 31, '02, BOS @ WAS  22   2   100   1946   214
# 6         Devin Brown     Nov 4, '02, SAS @ MEM  24   8   465   9022  1174
# 7           Pat Burke  Oct 29, '02, ORL vs. PHI  29   3   127   1293   199
# 8        Caron Butler  Oct 30, '02, MIA vs. ORL  22  14   881  28333  4596
# 9       Rasual Butler  Oct 30, '02, MIA vs. ORL  23  13   809  17219  2293
# 10         Dan Dickau    Oct 30, '02, ATL @ NJN  24   6   300   4617   608
# ...

# %%
rookies.head()
# Out:
#              Player                     Debut Age Yrs    G     MP    FG  \
# 0  Robert Archibald     Nov 9, '02, MEM @ DEN  22   2   44    328    15
# 1      Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4  105    831   106
# 2      Mike Batiste     Nov 1, '02, MEM @ DET  25   1   75   1248   197
# 3      Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4  162   1884   247
# 4     Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13  861  26901  5847
#
#      FGA  3P 3PA  ...    PF    PTS   FG%   3P%   FT%  MP.1 PTS.1 TRB.1 AST.1  \
# 0     53   0   0  ...    59     51  .283   NaN  .429   7.5   1.2   1.6   0.4
# 1    172   3   8  ...   140    286  .616  .375  .740   7.9   2.7   1.7   0.2
# 2    467  18  81  ...   120    481  .422  .222  .784  16.6   6.4   3.4   0.7
# 3    530   1   5  ...   324    637  .466  .200  .657  11.6   3.9   2.9   0.2
# 4  11221   1  14  ...  2612  13976  .521  .071  .722  31.2  16.2   9.5   2.2
#
#    Year
# 0  2003
# 1  2003
# 2  2003
# 3  2003
# 4  2003
#
# ...

# %%
roys.head()
# Out:
#           Player  Year  Pts Won  Pts Max  Share
# 0       Yao Ming  2003    405.0      585  0.692
# 1   Caron Butler  2003    179.0      585  0.306
# 2  Manu Ginóbili  2003      5.0      585  0.009
# 3    Drew Gooden  2003      3.0      585  0.005
# 4           Nenê  2003      2.0      585  0.003

# %%
rookies
# Out:
#                   Player                     Debut Age Yrs    G     MP    FG  \
# 0       Robert Archibald     Nov 9, '02, MEM @ DEN  22   2   44    328    15
# 1           Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4  105    831   106
# 2           Mike Batiste     Nov 1, '02, MEM @ DET  25   1   75   1248   197
# 3           Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4  162   1884   247
# 4          Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13  861  26901  5847
# ...                  ...                       ...  ..  ..  ...    ...   ...
# 1894      Jalen Williams    Oct 19, '22, OKC @ MIN  21   2  105   3232   619
# 1895     Jaylin Williams  Oct 23, '22, OKC vs. MIN  20   2   77   1246   136
# 1896  Jeenathan Williams     Apr 2, '23, POR @ MIN  23   2    9    149    30
# 1897       Mark Williams    Oct 19, '22, CHO @ SAS  21   2   62   1336   258
# 1898  Vince Williams Jr.    Oct 22, '22, MEM @ DAL  22   2   40    628    52
#
# ...

# %%
rookies.head()
# Out:
#              Player                     Debut Age Yrs    G     MP    FG  \
# 0  Robert Archibald     Nov 9, '02, MEM @ DEN  22   2   44    328    15
# 1      Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4  105    831   106
# 2      Mike Batiste     Nov 1, '02, MEM @ DET  25   1   75   1248   197
# 3      Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4  162   1884   247
# 4     Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13  861  26901  5847
#
#      FGA  3P 3PA  ...    PF    PTS   FG%   3P%   FT%  MP.1 PTS.1 TRB.1 AST.1  \
# 0     53   0   0  ...    59     51  .283   NaN  .429   7.5   1.2   1.6   0.4
# 1    172   3   8  ...   140    286  .616  .375  .740   7.9   2.7   1.7   0.2
# 2    467  18  81  ...   120    481  .422  .222  .784  16.6   6.4   3.4   0.7
# 3    530   1   5  ...   324    637  .466  .200  .657  11.6   3.9   2.9   0.2
# 4  11221   1  14  ...  2612  13976  .521  .071  .722  31.2  16.2   9.5   2.2
#
#    Year
# 0  2003
# 1  2003
# 2  2003
# 3  2003
# 4  2003
#
# ...

# %%
rookies["Player"].head(50)
# Out:
# 0       Robert Archibald
# 1           Maceo Baston
# 2           Mike Batiste
# 3           Lonny Baxter
# 4          Carlos Boozer
# 5            J.R. Bremer
# 6            Devin Brown
# 7              Pat Burke
# 8           Caron Butler
# 9          Rasual Butler
# 10            Dan Dickau
# 11            Juan Dixon
# 12         Mike Dunleavy
# 13            Melvin Ely
# 14          Reggie Evans
# 15          Dan Gadzuric
# 16        Manu Ginóbili*
# 17        Gordan Giriček
# 18           Drew Gooden
# 19        Marcus Haislip
# 22       Adam Harrington
# 23     Junior Harrington
# 24       Juaquin Hawkins
# 25                  Nenê
# 26          Nate Huffman
# 27         Ryan Humphrey
# 28        Casey Jacobsen
# 29           Marko Jarić
# 30       Chris Jefferies
# 31        Jared Jeffries
# 32           Ken Johnson
# 33            Fred Jones
# 34          Sean Lampley
# 35           Tito Maddox
# 36           Roger Mason
# 37             Yao Ming*
# 38         Ronald Murray
# ...

# %%
rookies["Player"] = rookies["Player"].str.replace("*", "", regex=False)

# %%
rookies.head(50)
# Out:
#                 Player                     Debut Age Yrs     G     MP    FG  \
# 0     Robert Archibald     Nov 9, '02, MEM @ DEN  22   2    44    328    15
# 1         Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4   105    831   106
# 2         Mike Batiste     Nov 1, '02, MEM @ DET  25   1    75   1248   197
# 3         Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4   162   1884   247
# 4        Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13   861  26901  5847
# 5          J.R. Bremer    Oct 31, '02, BOS @ WAS  22   2   100   1946   214
# 6          Devin Brown     Nov 4, '02, SAS @ MEM  24   8   465   9022  1174
# 7            Pat Burke  Oct 29, '02, ORL vs. PHI  29   3   127   1293   199
# 8         Caron Butler  Oct 30, '02, MIA vs. ORL  22  14   881  28333  4596
# 9        Rasual Butler  Oct 30, '02, MIA vs. ORL  23  13   809  17219  2293
# 10          Dan Dickau    Oct 30, '02, ATL @ NJN  24   6   300   4617   608
# ...

# %%
rookies.head(20)
# Out:
#               Player                     Debut Age Yrs     G     MP    FG  \
# 0   Robert Archibald     Nov 9, '02, MEM @ DEN  22   2    44    328    15
# 1       Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4   105    831   106
# 2       Mike Batiste     Nov 1, '02, MEM @ DET  25   1    75   1248   197
# 3       Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4   162   1884   247
# 4      Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13   861  26901  5847
# 5        J.R. Bremer    Oct 31, '02, BOS @ WAS  22   2   100   1946   214
# 6        Devin Brown     Nov 4, '02, SAS @ MEM  24   8   465   9022  1174
# 7          Pat Burke  Oct 29, '02, ORL vs. PHI  29   3   127   1293   199
# 8       Caron Butler  Oct 30, '02, MIA vs. ORL  22  14   881  28333  4596
# 9      Rasual Butler  Oct 30, '02, MIA vs. ORL  23  13   809  17219  2293
# 10        Dan Dickau    Oct 30, '02, ATL @ NJN  24   6   300   4617   608
# 11        Juan Dixon  Oct 31, '02, WAS vs. BOS  24   7   436   8509  1400
# ...

# %%
# rookies.groupby(["Player", "Year"])

# %%
# def single_row(df):
#     if df.shape[0]==1:
#         return df
#     else:
#         row = df[df["Tm"] == "TOT"]
#         row["Tm"] = df.iloc[-1,:]["Tm"]
#         return row
    
# rookies = rookies.groupby(["Player", "Year"]).apply(single_row)

# %%
combined = rookies.merge(roys, how="outer", on=["Player", "Year"])

# %%
combined.head(5)
# Out:
#              Player                     Debut Age Yrs    G     MP    FG  \
# 0  Robert Archibald     Nov 9, '02, MEM @ DEN  22   2   44    328    15
# 1      Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4  105    831   106
# 2      Mike Batiste     Nov 1, '02, MEM @ DET  25   1   75   1248   197
# 3      Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4  162   1884   247
# 4     Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13  861  26901  5847
#
#      FGA  3P 3PA  ...   3P%   FT%  MP.1 PTS.1 TRB.1 AST.1  Year Pts Won  \
# 0     53   0   0  ...   NaN  .429   7.5   1.2   1.6   0.4  2003     NaN
# 1    172   3   8  ...  .375  .740   7.9   2.7   1.7   0.2  2003     NaN
# 2    467  18  81  ...  .222  .784  16.6   6.4   3.4   0.7  2003     NaN
# 3    530   1   5  ...  .200  .657  11.6   3.9   2.9   0.2  2003     NaN
# 4  11221   1  14  ...  .071  .722  31.2  16.2   9.5   2.2  2003     1.0
#
#   Pts Max  Share
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# ...

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined
# Out:
#                   Player                     Debut Age Yrs    G     MP    FG  \
# 0       Robert Archibald     Nov 9, '02, MEM @ DEN  22   2   44    328    15
# 1           Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4  105    831   106
# 2           Mike Batiste     Nov 1, '02, MEM @ DET  25   1   75   1248   197
# 3           Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4  162   1884   247
# 4          Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13  861  26901  5847
# ...                  ...                       ...  ..  ..  ...    ...   ...
# 1740      Jalen Williams    Oct 19, '22, OKC @ MIN  21   2  105   3232   619
# 1741     Jaylin Williams  Oct 23, '22, OKC vs. MIN  20   2   77   1246   136
# 1742  Jeenathan Williams     Apr 2, '23, POR @ MIN  23   2    9    149    30
# 1743       Mark Williams    Oct 19, '22, CHO @ SAS  21   2   62   1336   258
# 1744  Vince Williams Jr.    Oct 22, '22, MEM @ DAL  22   2   40    628    52
#
# ...

# %%
combined.to_csv("combined.csv")

# %%
rookies
# Out:
#                   Player                     Debut Age Yrs    G     MP    FG  \
# 0       Robert Archibald     Nov 9, '02, MEM @ DEN  22   2   44    328    15
# 1           Maceo Baston  Feb 12, '03, TOR vs. ATL  27   4  105    831   106
# 2           Mike Batiste     Nov 1, '02, MEM @ DET  25   1   75   1248   197
# 3           Lonny Baxter   Nov 1, '02, CHI vs. NOH  24   4  162   1884   247
# 4          Carlos Boozer    Oct 29, '02, CLE @ SAC  21  13  861  26901  5847
# ...                  ...                       ...  ..  ..  ...    ...   ...
# 1894      Jalen Williams    Oct 19, '22, OKC @ MIN  21   2  105   3232   619
# 1895     Jaylin Williams  Oct 23, '22, OKC vs. MIN  20   2   77   1246   136
# 1896  Jeenathan Williams     Apr 2, '23, POR @ MIN  23   2    9    149    30
# 1897       Mark Williams    Oct 19, '22, CHO @ SAS  21   2   62   1336   258
# 1898  Vince Williams Jr.    Oct 22, '22, MEM @ DAL  22   2   40    628    52
#
# ...

# %%
del combined["Debut"]

# %%
combined
# Out:
#                   Player Age Yrs    G     MP    FG    FGA   3P  3PA    FT  \
# 0       Robert Archibald  22   2   44    328    15     53    0    0    21
# 1           Maceo Baston  27   4  105    831   106    172    3    8    71
# 2           Mike Batiste  25   1   75   1248   197    467   18   81    69
# 3           Lonny Baxter  24   4  162   1884   247    530    1    5   142
# 4          Carlos Boozer  21  13  861  26901  5847  11221    1   14  2281
# ...                  ...  ..  ..  ...    ...   ...    ...  ...  ...   ...
# 1740      Jalen Williams  21   2  105   3232   619   1182  113  297   245
# 1741     Jaylin Williams  20   2   77   1246   136    322   65  169    52
# 1742  Jeenathan Williams  23   2    9    149    30     50    3   10     3
# 1743       Mark Williams  21   2   62   1336   258    402    0    0   113
# 1744  Vince Williams Jr.  22   2   40    628    52    149   32  113    28
#
#       ...   3P%   FT%  MP.1 PTS.1 TRB.1 AST.1  Year Pts Won Pts Max  Share
# ...

# %%
combined.dtypes
# Out:
# Player      object
# Age         object
# Yrs         object
# G           object
# MP          object
# FG          object
# FGA         object
# 3P          object
# 3PA         object
# FT          object
# FTA         object
# ORB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# FG%         object
# 3P%         object
# FT%         object
# MP.1        object
# PTS.1       object
# TRB.1       object
# AST.1       object
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# dtype: object

# %%
combined = combined.apply(pd.to_numeric, errors="ignore")

# %%
combined.dtypes
# Out:
# Player      object
# Age          int64
# Yrs          int64
# G            int64
# MP           int64
# FG           int64
# FGA          int64
# 3P           int64
# 3PA          int64
# FT           int64
# FTA          int64
# ORB          int64
# TRB          int64
# AST          int64
# STL          int64
# BLK          int64
# TOV          int64
# PF           int64
# PTS          int64
# FG%        float64
# 3P%        float64
# FT%        float64
# MP.1       float64
# PTS.1      float64
# TRB.1      float64
# AST.1      float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# dtype: object

# %%
combined.to_csv("rookie_roy_stats.csv")

# %%
highest_scoring = combined[combined["G"] > 70].sort_values("PTS", ascending=False).head(10)

# %%
highest_scoring.plot.bar("Player", "PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
combined.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))
# Out:
#                           Player  Age  Yrs     G     MP     FG    FGA    3P  \
# Year
# 2003 53        Amar'e Stoudemire   20   14   846  26254   5911  11009    30
# 2004 101            LeBron James   19   21  1453  55191  14450  28608  2331
# 2005 157           Dwight Howard   19   18  1242  39457   7051  12016    22
# 2006 256              Chris Paul   20   19  1245  42644   7793  16542  1683
# 2007 288       LaMarcus Aldridge   21   16  1076  36242   8311  16872   227
# 2008 382            Kevin Durant   19   16  1014  37220   9489  18991  1924
# 2009 488       Russell Westbrook   20   16  1127  38337   8904  20319  1252
# 2010 520            James Harden   20   15  1028  35706   7438  16806  2832
# 2011 576             Paul George   20   14   824  27753   5821  13293  2113
# 2012 645            Kyrie Irving   19   13   690  23647   5940  12580  1608
# 2013 738          Damian Lillard   22   12   802  29108   6526  14867  2489
# ...

# %% [markdown]
# highest_scoring.plot.bar("Year", "PTS")

# %%
combined.corr(numeric_only = True)["Share"]
# Out:
# Age       -0.137759
# Yrs        0.211903
# G          0.224497
# MP         0.310732
# FG         0.398421
# FGA        0.391708
# 3P         0.293262
# 3PA        0.299868
# FT         0.415609
# FTA        0.406394
# ORB        0.211970
# TRB        0.287855
# AST        0.381099
# STL        0.310414
# BLK        0.237546
# TOV        0.390578
# PF         0.253274
# PTS        0.404261
# FG%        0.077213
# 3P%        0.062644
# FT%        0.081885
# MP.1       0.342632
# PTS.1      0.463292
# TRB.1      0.296390
# AST.1      0.406496
# Year      -0.023605
# Pts Won    0.994746
# Pts Max    0.539142
# Share      1.000000
# Name: Share, dtype: float64

# %%
combined.corr(numeric_only = True)["Share"].plot.bar()
# Out:
# <Axes: >

# %%
current_rookies = pd.read_csv("current_rookies.csv")

# %%
del current_rookies["Unnamed: 0"]
del current_rookies["Rk"]
del current_rookies["Debut"]

# %%
current_rookies = current_rookies[~current_rookies["MP"].str.contains("Totals", na=False)]
current_rookies = current_rookies[~current_rookies["Age"].str.contains("Age", na=False)]

# %%
current_rookies.dtypes
# Out:
# Player    object
# Age       object
# Yrs       object
# G         object
# MP        object
# FG        object
# FGA       object
# 3P        object
# 3PA       object
# FT        object
# FTA       object
# ORB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# FG%       object
# 3P%       object
# FT%       object
# MP.1      object
# PTS.1     object
# TRB.1     object
# AST.1     object
# Year       int64
# dtype: object

# %%
current_rookies = current_rookies.apply(pd.to_numeric, errors="ignore")

# %%
current_rookies.dtypes
# Out:
# Player     object
# Age         int64
# Yrs         int64
# G           int64
# MP          int64
# FG          int64
# FGA         int64
# 3P          int64
# 3PA         int64
# FT          int64
# FTA         int64
# ORB         int64
# TRB         int64
# AST         int64
# STL         int64
# BLK         int64
# TOV         int64
# PF          int64
# PTS         int64
# FG%       float64
# 3P%       float64
# FT%       float64
# MP.1      float64
# PTS.1     float64
# TRB.1     float64
# AST.1     float64
# Year        int64
# dtype: object

# %%
current_rookies.head(30)
# Out:
#                  Player  Age  Yrs   G   MP   FG  FGA  3P  3PA  FT  ...  PF  \
# 0            Ibou Badji   21    1   5   65    5    7   0    0   3  ...  18
# 1          Amari Bailey   19    1   2   11    2    6   0    2   1  ...   0
# 2           Emoni Bates   20    1  10   76    6   25   5   20   1  ...   5
# 3         Jules Bernard   24    1   2   10    1    5   0    3   0  ...   1
# 4         Onuralp Bitim   24    1   1    3    0    0   0    0   0  ...   0
# 5         Anthony Black   20    1  32  662   67  132  17   47  22  ...  69
# 6           Leaky Black   24    1   7   40    5    8   1    2   0  ...   2
# 7            Kobe Brown   24    1  22  234   22   54  11   35   1  ...  36
# 8           Kobe Bufkin   20    1   2    4    0    3   0    1   1  ...   0
# 9        Toumani Camara   23    1  32  795   85  206  27   89  30  ...  88
# 10      Colin Castleton   23    1   4   28    5    8   0    0   2  ...   5
# ...

# %%
current_rookies.to_csv("cleaned_current_rookies.csv")
